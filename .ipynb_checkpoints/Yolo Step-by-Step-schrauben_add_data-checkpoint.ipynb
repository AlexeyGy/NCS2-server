# %% [markdown]
# **Outline of Steps**
#     + Initialization
#         + Download COCO detection data from http://cocodataset.org/#download
#             + http://images.cocodataset.org/zips/train2014.zip <= train images
#             + http://images.cocodataset.org/zips/val2014.zip <= validation images
#             + http://images.cocodataset.org/annotations/annotations_trainval2014.zip <= train and validation annotations
#         + Run this script to convert annotations in COCO format to VOC format
#             + https://gist.github.com/chicham/6ed3842d0d2014987186#file-coco2pascal-py
#         + Download pre-trained weights from https://pjreddie.com/darknet/yolo/
#             + https://pjreddie.com/media/files/yolo.weights
#         + Specify the directory of train annotations (train_annot_folder) and train images (train_image_folder)
#         + Specify the directory of validation annotations (valid_annot_folder) and validation images (valid_image_folder)
#         + Specity the path of pre-trained weights by setting variable *wt_path*
#     + Construct equivalent network in Keras
#         + Network arch from https://github.com/pjreddie/darknet/blob/master/cfg/yolo-voc.cfg
#     + Load the pretrained weights
#     + Perform training
#     + Perform detection on an image with newly trained weights
#     + Perform detection on an video with newly trained weights

# %% [markdown]
# # Initialization

# %%
from keras.models import Sequential, Model
from keras.layers import Reshape, Activation, Conv2D, Input, MaxPooling2D, BatchNormalization, Flatten, Dense, Lambda
from keras.layers.advanced_activations import LeakyReLU
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
from keras.optimizers import SGD, Adam, RMSprop
from keras.layers.merge import concatenate
import matplotlib.pyplot as plt
import keras.backend as K
import tensorflow as tf
#import imgaug as ia
from tqdm import tqdm
#from imgaug import augmenters as iaa
import numpy as np
import pickle
import os, cv2
from preprocessing import parse_annotation, BatchGenerator
from utils import WeightReader, decode_netout, draw_boxes

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %matplotlib inline
# Out:
# /home/alexey/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#LABELS = ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']
LABELS = ['Schraube','Duebel','Montiert','kleine_Schraube']
IMAGE_H, IMAGE_W = 416, 416
GRID_H,  GRID_W  = 13 , 13
BOX              = 5
CLASS            = len(LABELS)
CLASS_WEIGHTS    = np.ones(CLASS, dtype='float32')
OBJ_THRESHOLD    = 0.2#0.5
NMS_THRESHOLD    = 0.2#0.45
ANCHORS          = [0.57273, 0.677385, 1.87446, 2.06253, 3.33843, 5.47434, 7.88282, 3.52778, 9.77052, 9.16828]

NO_OBJECT_SCALE  = 1.0
OBJECT_SCALE     = 5.0
COORD_SCALE      = 1.0
CLASS_SCALE      = 1.0

BATCH_SIZE       = 5
WARM_UP_BATCHES  = 1
TRUE_BOX_BUFFER  = 50

# %% [markdown]
# wt_path = 'yolo.weights'
# train_image_folder = './data/coco/train2014/'
# train_annot_folder = './data/coco/annotations_voc/'
# valid_image_folder = './data/coco/val2014/'
# valid_annot_folder = './data/coco/annotations_voc_val//'

# %%
wt_path = 'yolo.weights'                      
train_image_folder = '../data/raw/'
train_annot_folder = '../data/labels/train/'
valid_image_folder = train_image_folder
valid_annot_folder = '../data/labels/val/'

# %% [markdown]
# # Construct the network

# %%
# the function to implement the orgnization layer (thanks to github.com/allanzelener/YAD2K)
def space_to_depth_x2(x):
    return tf.space_to_depth(x, block_size=2)

# %%
input_image = Input(shape=(IMAGE_H, IMAGE_W, 3))
true_boxes  = Input(shape=(1, 1, 1, TRUE_BOX_BUFFER , 4))

# Layer 1
x = Conv2D(32, (3,3), strides=(1,1), padding='same', name='conv_1', use_bias=False)(input_image)
x = BatchNormalization(name='norm_1')(x)
x = LeakyReLU(alpha=0.1)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 2
x = Conv2D(64, (3,3), strides=(1,1), padding='same', name='conv_2', use_bias=False)(x)
x = BatchNormalization(name='norm_2')(x)
x = LeakyReLU(alpha=0.1)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 3
x = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_3', use_bias=False)(x)
x = BatchNormalization(name='norm_3')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 4
x = Conv2D(64, (1,1), strides=(1,1), padding='same', name='conv_4', use_bias=False)(x)
x = BatchNormalization(name='norm_4')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 5
x = Conv2D(128, (3,3), strides=(1,1), padding='same', name='conv_5', use_bias=False)(x)
x = BatchNormalization(name='norm_5')(x)
x = LeakyReLU(alpha=0.1)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 6
x = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_6', use_bias=False)(x)
x = BatchNormalization(name='norm_6')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 7
x = Conv2D(128, (1,1), strides=(1,1), padding='same', name='conv_7', use_bias=False)(x)
x = BatchNormalization(name='norm_7')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 8
x = Conv2D(256, (3,3), strides=(1,1), padding='same', name='conv_8', use_bias=False)(x)
x = BatchNormalization(name='norm_8')(x)
x = LeakyReLU(alpha=0.1)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 9
x = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_9', use_bias=False)(x)
x = BatchNormalization(name='norm_9')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 10
x = Conv2D(256, (1,1), strides=(1,1), padding='same', name='conv_10', use_bias=False)(x)
x = BatchNormalization(name='norm_10')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 11
x = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_11', use_bias=False)(x)
x = BatchNormalization(name='norm_11')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 12
x = Conv2D(256, (1,1), strides=(1,1), padding='same', name='conv_12', use_bias=False)(x)
x = BatchNormalization(name='norm_12')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 13
x = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_13', use_bias=False)(x)
x = BatchNormalization(name='norm_13')(x)
x = LeakyReLU(alpha=0.1)(x)

skip_connection = x

x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 14
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_14', use_bias=False)(x)
x = BatchNormalization(name='norm_14')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 15
x = Conv2D(512, (1,1), strides=(1,1), padding='same', name='conv_15', use_bias=False)(x)
x = BatchNormalization(name='norm_15')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 16
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_16', use_bias=False)(x)
x = BatchNormalization(name='norm_16')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 17
x = Conv2D(512, (1,1), strides=(1,1), padding='same', name='conv_17', use_bias=False)(x)
x = BatchNormalization(name='norm_17')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 18
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_18', use_bias=False)(x)
x = BatchNormalization(name='norm_18')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 19
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_19', use_bias=False)(x)
x = BatchNormalization(name='norm_19')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 20
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_20', use_bias=False)(x)
x = BatchNormalization(name='norm_20')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 21
skip_connection = Conv2D(64, (1,1), strides=(1,1), padding='same', name='conv_21', use_bias=False)(skip_connection)
skip_connection = BatchNormalization(name='norm_21')(skip_connection)
skip_connection = LeakyReLU(alpha=0.1)(skip_connection)
skip_connection = Lambda(space_to_depth_x2)(skip_connection)

x = concatenate([skip_connection, x])

# Layer 22
x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_22', use_bias=False)(x)
x = BatchNormalization(name='norm_22')(x)
x = LeakyReLU(alpha=0.1)(x)

# Layer 23
x = Conv2D(BOX * (4 + 1 + CLASS), (1,1), strides=(1,1), padding='same', name='conv_23')(x)
output = Reshape((GRID_H, GRID_W, BOX, 4 + 1 + CLASS))(x)

# small hack to allow true_boxes to be registered when Keras build the model 
# for more information: https://github.com/fchollet/keras/issues/2790
output = Lambda(lambda args: args[0])([output, true_boxes])

model = Model([input_image, true_boxes], output)

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 416, 416, 3)  0
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 416, 416, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# norm_1 (BatchNormalization)     (None, 416, 416, 32) 128         conv_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 416, 416, 32) 0           norm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 208, 208, 32) 0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, 208, 208, 64) 18432       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# norm_2 (BatchNormalization)     (None, 208, 208, 64) 256         conv_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 208, 208, 64) 0           norm_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 104, 104, 64) 0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv2D)                 (None, 104, 104, 128 73728       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# norm_3 (BatchNormalization)     (None, 104, 104, 128 512         conv_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 104, 104, 128 0           norm_3[0][0]
# __________________________________________________________________________________________________
# conv_4 (Conv2D)                 (None, 104, 104, 64) 8192        leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# norm_4 (BatchNormalization)     (None, 104, 104, 64) 256         conv_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 104, 104, 64) 0           norm_4[0][0]
# __________________________________________________________________________________________________
# conv_5 (Conv2D)                 (None, 104, 104, 128 73728       leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# norm_5 (BatchNormalization)     (None, 104, 104, 128 512         conv_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 104, 104, 128 0           norm_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 52, 52, 128)  0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv_6 (Conv2D)                 (None, 52, 52, 256)  294912      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# norm_6 (BatchNormalization)     (None, 52, 52, 256)  1024        conv_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 52, 52, 256)  0           norm_6[0][0]
# __________________________________________________________________________________________________
# conv_7 (Conv2D)                 (None, 52, 52, 128)  32768       leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# norm_7 (BatchNormalization)     (None, 52, 52, 128)  512         conv_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 52, 52, 128)  0           norm_7[0][0]
# __________________________________________________________________________________________________
# conv_8 (Conv2D)                 (None, 52, 52, 256)  294912      leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# norm_8 (BatchNormalization)     (None, 52, 52, 256)  1024        conv_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 52, 52, 256)  0           norm_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 26, 26, 256)  0           leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv_9 (Conv2D)                 (None, 26, 26, 512)  1179648     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# norm_9 (BatchNormalization)     (None, 26, 26, 512)  2048        conv_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 26, 26, 512)  0           norm_9[0][0]
# __________________________________________________________________________________________________
# conv_10 (Conv2D)                (None, 26, 26, 256)  131072      leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# norm_10 (BatchNormalization)    (None, 26, 26, 256)  1024        conv_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 26, 26, 256)  0           norm_10[0][0]
# __________________________________________________________________________________________________
# conv_11 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# norm_11 (BatchNormalization)    (None, 26, 26, 512)  2048        conv_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 26, 26, 512)  0           norm_11[0][0]
# __________________________________________________________________________________________________
# conv_12 (Conv2D)                (None, 26, 26, 256)  131072      leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# norm_12 (BatchNormalization)    (None, 26, 26, 256)  1024        conv_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 26, 26, 256)  0           norm_12[0][0]
# __________________________________________________________________________________________________
# conv_13 (Conv2D)                (None, 26, 26, 512)  1179648     leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# norm_13 (BatchNormalization)    (None, 26, 26, 512)  2048        conv_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 26, 26, 512)  0           norm_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 13, 13, 512)  0           leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# conv_14 (Conv2D)                (None, 13, 13, 1024) 4718592     max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# norm_14 (BatchNormalization)    (None, 13, 13, 1024) 4096        conv_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 13, 13, 1024) 0           norm_14[0][0]
# __________________________________________________________________________________________________
# conv_15 (Conv2D)                (None, 13, 13, 512)  524288      leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# norm_15 (BatchNormalization)    (None, 13, 13, 512)  2048        conv_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 13, 13, 512)  0           norm_15[0][0]
# __________________________________________________________________________________________________
# conv_16 (Conv2D)                (None, 13, 13, 1024) 4718592     leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# norm_16 (BatchNormalization)    (None, 13, 13, 1024) 4096        conv_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 13, 13, 1024) 0           norm_16[0][0]
# __________________________________________________________________________________________________
# conv_17 (Conv2D)                (None, 13, 13, 512)  524288      leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# norm_17 (BatchNormalization)    (None, 13, 13, 512)  2048        conv_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 13, 13, 512)  0           norm_17[0][0]
# __________________________________________________________________________________________________
# conv_18 (Conv2D)                (None, 13, 13, 1024) 4718592     leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# norm_18 (BatchNormalization)    (None, 13, 13, 1024) 4096        conv_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 13, 13, 1024) 0           norm_18[0][0]
# __________________________________________________________________________________________________
# conv_19 (Conv2D)                (None, 13, 13, 1024) 9437184     leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# norm_19 (BatchNormalization)    (None, 13, 13, 1024) 4096        conv_19[0][0]
# __________________________________________________________________________________________________
# conv_21 (Conv2D)                (None, 26, 26, 64)   32768       leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 13, 13, 1024) 0           norm_19[0][0]
# __________________________________________________________________________________________________
# norm_21 (BatchNormalization)    (None, 26, 26, 64)   256         conv_21[0][0]
# __________________________________________________________________________________________________
# conv_20 (Conv2D)                (None, 13, 13, 1024) 9437184     leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 26, 26, 64)   0           norm_21[0][0]
# __________________________________________________________________________________________________
# norm_20 (BatchNormalization)    (None, 13, 13, 1024) 4096        conv_20[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 13, 13, 256)  0           leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 13, 13, 1024) 0           norm_20[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 13, 13, 1280) 0           lambda_1[0][0]
#                                                                  leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# conv_22 (Conv2D)                (None, 13, 13, 1024) 11796480    concatenate_1[0][0]
# __________________________________________________________________________________________________
# norm_22 (BatchNormalization)    (None, 13, 13, 1024) 4096        conv_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 13, 13, 1024) 0           norm_22[0][0]
# __________________________________________________________________________________________________
# conv_23 (Conv2D)                (None, 13, 13, 45)   46125       leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 13, 13, 5, 9) 0           conv_23[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1, 1, 1, 50,  0
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 13, 13, 5, 9) 0           reshape_1[0][0]
#                                                                  input_2[0][0]
# ==================================================================================================
# Total params: 50,594,061
# Trainable params: 50,573,389
# Non-trainable params: 20,672
# __________________________________________________________________________________________________

# %% [markdown]
# # Load pretrained weights

# %% [markdown]
# **Load the weights originally provided by YOLO**

# %%
weight_reader = WeightReader(wt_path)

weight_reader.reset()
nb_conv = 23

for i in range(1, nb_conv+1):
    conv_layer = model.get_layer('conv_' + str(i))
    
    if i < nb_conv:
        norm_layer = model.get_layer('norm_' + str(i))
        
        size = np.prod(norm_layer.get_weights()[0].shape)

        beta  = weight_reader.read_bytes(size)
        gamma = weight_reader.read_bytes(size)
        mean  = weight_reader.read_bytes(size)
        var   = weight_reader.read_bytes(size)

        weights = norm_layer.set_weights([gamma, beta, mean, var])       
        
    if len(conv_layer.get_weights()) > 1:
        bias   = weight_reader.read_bytes(np.prod(conv_layer.get_weights()[1].shape))
        kernel = weight_reader.read_bytes(np.prod(conv_layer.get_weights()[0].shape))
        kernel = kernel.reshape(list(reversed(conv_layer.get_weights()[0].shape)))
        kernel = kernel.transpose([2,3,1,0])
        conv_layer.set_weights([kernel, bias])
    else:
        kernel = weight_reader.read_bytes(np.prod(conv_layer.get_weights()[0].shape))
        kernel = kernel.reshape(list(reversed(conv_layer.get_weights()[0].shape)))
        kernel = kernel.transpose([2,3,1,0])
        conv_layer.set_weights([kernel])

# %% [markdown]
# **Randomize weights of the last layer**

# %%
layer   = model.layers[-4] # the last convolutional layer
weights = layer.get_weights()

new_kernel = np.random.normal(size=weights[0].shape)/(GRID_H*GRID_W)
new_bias   = np.random.normal(size=weights[1].shape)/(GRID_H*GRID_W)

layer.set_weights([new_kernel, new_bias])

# %% [markdown]
# # Perform training

# %% [markdown]
# **Loss function**

# %% [markdown]
# $$\begin{multline}
# \lambda_\textbf{coord}
# \sum_{i = 0}^{S^2}
#     \sum_{j = 0}^{B}
#      L_{ij}^{\text{obj}}
#             \left[
#             \left(
#                 x_i - \hat{x}_i
#             \right)^2 +
#             \left(
#                 y_i - \hat{y}_i
#             \right)^2
#             \right]
# \\
# + \lambda_\textbf{coord}
# \sum_{i = 0}^{S^2}
#     \sum_{j = 0}^{B}
#          L_{ij}^{\text{obj}}
#          \left[
#         \left(
#             \sqrt{w_i} - \sqrt{\hat{w}_i}
#         \right)^2 +
#         \left(
#             \sqrt{h_i} - \sqrt{\hat{h}_i}
#         \right)^2
#         \right]
# \\
# + \sum_{i = 0}^{S^2}
#     \sum_{j = 0}^{B}
#         L_{ij}^{\text{obj}}
#         \left(
#             C_i - \hat{C}_i
#         \right)^2
# \\
# + \lambda_\textrm{noobj}
# \sum_{i = 0}^{S^2}
#     \sum_{j = 0}^{B}
#     L_{ij}^{\text{noobj}}
#         \left(
#             C_i - \hat{C}_i
#         \right)^2
# \\
# + \sum_{i = 0}^{S^2}
# L_i^{\text{obj}}
#     \sum_{c \in \textrm{classes}}
#         \left(
#             p_i(c) - \hat{p}_i(c)
#         \right)^2
# \end{multline}$$

# %%
def custom_loss(y_true, y_pred):
    mask_shape = tf.shape(y_true)[:4]
    
    cell_x = tf.to_float(tf.reshape(tf.tile(tf.range(GRID_W), [GRID_H]), (1, GRID_H, GRID_W, 1, 1)))
    cell_y = tf.transpose(cell_x, (0,2,1,3,4))

    cell_grid = tf.tile(tf.concat([cell_x,cell_y], -1), [BATCH_SIZE, 1, 1, 5, 1])
    
    coord_mask = tf.zeros(mask_shape)
    conf_mask  = tf.zeros(mask_shape)
    class_mask = tf.zeros(mask_shape)
    
    seen = tf.Variable(0.)
    total_recall = tf.Variable(0.)
    
    """
    Adjust prediction
    """
    ### adjust x and y      
    pred_box_xy = tf.sigmoid(y_pred[..., :2]) + cell_grid
    
    ### adjust w and h
    pred_box_wh = tf.exp(y_pred[..., 2:4]) * np.reshape(ANCHORS, [1,1,1,BOX,2])
    
    ### adjust confidence
    pred_box_conf = tf.sigmoid(y_pred[..., 4])
    
    ### adjust class probabilities
    pred_box_class = y_pred[..., 5:]
    
    """
    Adjust ground truth
    """
    ### adjust x and y
    true_box_xy = y_true[..., 0:2] # relative position to the containing cell
    
    ### adjust w and h
    true_box_wh = y_true[..., 2:4] # number of cells accross, horizontally and vertically
    
    ### adjust confidence
    true_wh_half = true_box_wh / 2.
    true_mins    = true_box_xy - true_wh_half
    true_maxes   = true_box_xy + true_wh_half
    
    pred_wh_half = pred_box_wh / 2.
    pred_mins    = pred_box_xy - pred_wh_half
    pred_maxes   = pred_box_xy + pred_wh_half       
    
    intersect_mins  = tf.maximum(pred_mins,  true_mins)
    intersect_maxes = tf.minimum(pred_maxes, true_maxes)
    intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
    intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]
    
    true_areas = true_box_wh[..., 0] * true_box_wh[..., 1]
    pred_areas = pred_box_wh[..., 0] * pred_box_wh[..., 1]

    union_areas = pred_areas + true_areas - intersect_areas
    iou_scores  = tf.truediv(intersect_areas, union_areas)
    
    true_box_conf = iou_scores * y_true[..., 4]
    
    ### adjust class probabilities
    true_box_class = tf.argmax(y_true[..., 5:], -1)
    
    """
    Determine the masks
    """
    ### coordinate mask: simply the position of the ground truth boxes (the predictors)
    coord_mask = tf.expand_dims(y_true[..., 4], axis=-1) * COORD_SCALE
    
    ### confidence mask: penelize predictors + penalize boxes with low IOU
    # penalize the confidence of the boxes, which have IOU with some ground truth box < 0.6
    true_xy = true_boxes[..., 0:2]
    true_wh = true_boxes[..., 2:4]
    
    true_wh_half = true_wh / 2.
    true_mins    = true_xy - true_wh_half
    true_maxes   = true_xy + true_wh_half
    
    pred_xy = tf.expand_dims(pred_box_xy, 4)
    pred_wh = tf.expand_dims(pred_box_wh, 4)
    
    pred_wh_half = pred_wh / 2.
    pred_mins    = pred_xy - pred_wh_half
    pred_maxes   = pred_xy + pred_wh_half    
    
    intersect_mins  = tf.maximum(pred_mins,  true_mins)
    intersect_maxes = tf.minimum(pred_maxes, true_maxes)
    intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
    intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]
    
    true_areas = true_wh[..., 0] * true_wh[..., 1]
    pred_areas = pred_wh[..., 0] * pred_wh[..., 1]

    union_areas = pred_areas + true_areas - intersect_areas
    iou_scores  = tf.truediv(intersect_areas, union_areas)

    best_ious = tf.reduce_max(iou_scores, axis=4)
    conf_mask = conf_mask + tf.to_float(best_ious < 0.6) * (1 - y_true[..., 4]) * NO_OBJECT_SCALE
    
    # penalize the confidence of the boxes, which are reponsible for corresponding ground truth box
    conf_mask = conf_mask + y_true[..., 4] * OBJECT_SCALE
    
    ### class mask: simply the position of the ground truth boxes (the predictors)
    class_mask = y_true[..., 4] * tf.gather(CLASS_WEIGHTS, true_box_class) * CLASS_SCALE       
    
    """
    Warm-up training
    """
    no_boxes_mask = tf.to_float(coord_mask < COORD_SCALE/2.)
    seen = tf.assign_add(seen, 1.)
    
    true_box_xy, true_box_wh, coord_mask = tf.cond(tf.less(seen, WARM_UP_BATCHES), 
                          lambda: [true_box_xy + (0.5 + cell_grid) * no_boxes_mask, 
                                   true_box_wh + tf.ones_like(true_box_wh) * np.reshape(ANCHORS, [1,1,1,BOX,2]) * no_boxes_mask, 
                                   tf.ones_like(coord_mask)],
                          lambda: [true_box_xy, 
                                   true_box_wh,
                                   coord_mask])
    
    """
    Finalize the loss
    """
    nb_coord_box = tf.reduce_sum(tf.to_float(coord_mask > 0.0))
    nb_conf_box  = tf.reduce_sum(tf.to_float(conf_mask  > 0.0))
    nb_class_box = tf.reduce_sum(tf.to_float(class_mask > 0.0))
    
    loss_xy    = tf.reduce_sum(tf.square(true_box_xy-pred_box_xy)     * coord_mask) / (nb_coord_box + 1e-6) / 2.
    loss_wh    = tf.reduce_sum(tf.square(true_box_wh-pred_box_wh)     * coord_mask) / (nb_coord_box + 1e-6) / 2.
    loss_conf  = tf.reduce_sum(tf.square(true_box_conf-pred_box_conf) * conf_mask)  / (nb_conf_box  + 1e-6) / 2.
    loss_class = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=true_box_class, logits=pred_box_class)
    loss_class = tf.reduce_sum(loss_class * class_mask) / (nb_class_box + 1e-6)
    
    loss = loss_xy + loss_wh + loss_conf + loss_class
    
    nb_true_box = tf.reduce_sum(y_true[..., 4])
    nb_pred_box = tf.reduce_sum(tf.to_float(true_box_conf > 0.5) * tf.to_float(pred_box_conf > 0.3))

    """
    Debugging code
    """    
    current_recall = nb_pred_box/(nb_true_box + 1e-6)
    total_recall = tf.assign_add(total_recall, current_recall) 

    loss = tf.Print(loss, [tf.zeros((1))], message='Dummy Line \t', summarize=1000)
    loss = tf.Print(loss, [loss_xy], message='Loss XY \t', summarize=1000)
    loss = tf.Print(loss, [loss_wh], message='Loss WH \t', summarize=1000)
    loss = tf.Print(loss, [loss_conf], message='Loss Conf \t', summarize=1000)
    loss = tf.Print(loss, [loss_class], message='Loss Class \t', summarize=1000)
    loss = tf.Print(loss, [loss], message='Total Loss \t', summarize=1000)
    loss = tf.Print(loss, [current_recall], message='Current Recall \t', summarize=1000)
    loss = tf.Print(loss, [total_recall/seen], message='Average Recall \t', summarize=1000)
    
    return loss

# %% [markdown]
# **Parse the annotations to construct train generator and validation generator**

# %%
generator_config = {
    'IMAGE_H'         : IMAGE_H, 
    'IMAGE_W'         : IMAGE_W,
    'GRID_H'          : GRID_H,  
    'GRID_W'          : GRID_W,
    'BOX'             : BOX,
    'LABELS'          : LABELS,
    'CLASS'           : len(LABELS),
    'ANCHORS'         : ANCHORS,
    'BATCH_SIZE'      : BATCH_SIZE,
    'TRUE_BOX_BUFFER' : 50,
}

# %%
def normalize(image):
    return image / 255.

# %%
train_imgs, seen_train_labels = parse_annotation(train_annot_folder, train_image_folder, labels=LABELS)
### write parsed annotations to pickle for fast retrieval next time
#with open('train_imgs', 'wb') as fp:
#    pickle.dump(train_imgs, fp)

### read saved pickle of parsed annotations
#with open ('train_imgs', 'rb') as fp:
#    train_imgs = pickle.load(fp)
train_batch = BatchGenerator(train_imgs, generator_config, norm=normalize)

valid_imgs, seen_valid_labels = parse_annotation(valid_annot_folder, valid_image_folder, labels=LABELS)
### write parsed annotations to pickle for fast retrieval next time
#with open('valid_imgs', 'wb') as fp:
#    pickle.dump(valid_imgs, fp)

### read saved pickle of parsed annotations
#with open ('valid_imgs', 'rb') as fp:
#    valid_imgs = pickle.load(fp)
valid_batch = BatchGenerator(valid_imgs, generator_config, norm=normalize, jitter=False)

# %% [markdown]
# **Setup a few callbacks and start the training**

# %%
if not os.path.exists("logs"):
    os.makedirs("logs")
    
train_instance = 'schrauben_more_data' # just the name for weights and log files

optimizer = "adam"

train_instance = train_instance + "_" + optimizer

if optimizer == "adam":
    optimizer = Adam(lr=0.5e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
elif optimizer == "sgd":
    optimizer = SGD(lr=1e-4, decay=0.0005, momentum=0.9)
elif optimizer == "rms":
    optimizer = RMSprop(lr=1e-4, rho=0.9, epsilon=1e-08, decay=0.0)

tb_counter  = len([log for log in os.listdir(os.path.abspath('./logs')) if train_instance in log]) + 1
tensorboard = TensorBoard(log_dir=os.path.join(os.path.abspath('logs/'), train_instance + '_' + str(tb_counter)), 
                          histogram_freq=0, 
                          write_graph=True, 
                          write_images=False)

early_stop = EarlyStopping(monitor='val_loss', 
                           min_delta=0.001, 
                           patience=10, 
                           mode='min', 
                           verbose=1)

checkpoint = ModelCheckpoint('weights_' + train_instance + str(tb_counter) + '.h5', 
                             monitor='val_loss', 
                             verbose=1, 
                             save_best_only=True, 
                             mode='min', 
                             period=1)



model.compile(loss=custom_loss, optimizer=optimizer)

model.fit_generator(generator        = train_batch, 
                    steps_per_epoch  = len(train_batch), 
                    epochs           = 100, 
                    verbose          = 1,
                    validation_data  = valid_batch,
                    validation_steps = len(valid_batch),
                    callbacks        = [early_stop, checkpoint, tensorboard], 
                    max_queue_size   = 3)
# Out:
# Epoch 1/100
# 22/22 [==============================] - ETA: 2:31 - loss: 3.611 - ETA: 1:47 - loss: 3.581 - ETA: 2:06 - loss: 3.160 - ETA: 1:54 - loss: 2.979 - ETA: 1:45 - loss: 2.879 - ETA: 1:35 - loss: 2.947 - ETA: 1:23 - loss: 2.809 - ETA: 1:18 - loss: 2.741 - ETA: 1:09 - loss: 2.659 - ETA: 1:04 - loss: 2.624 - ETA: 58s - loss: 2.546 - ETA: 53s - loss: 2.55 - ETA: 49s - loss: 2.48 - ETA: 45s - loss: 2.42 - ETA: 39s - loss: 2.39 - ETA: 32s - loss: 2.39 - ETA: 28s - loss: 2.38 - ETA: 21s - loss: 2.42 - ETA: 16s - loss: 2.38 - ETA: 10s - loss: 2.35 - ETA: 5s - loss: 2.3239 - 121s 5s/step - loss: 2.2773 - val_loss: nan
# C:\ProgramData\Anaconda3\lib\site-packages\keras\callbacks.py:529: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# C:\ProgramData\Anaconda3\lib\site-packages\keras\callbacks.py:437: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current, self.best):
# Epoch 00001: val_loss did not improve
# Epoch 2/100
# 22/22 [==============================] - ETA: 32s - loss: 1.48 - ETA: 1:37 - loss: 1.345 - ETA: 1:54 - loss: 1.410 - ETA: 1:47 - loss: 1.379 - ETA: 1:38 - loss: 1.422 - ETA: 1:31 - loss: 1.445 - ETA: 1:26 - loss: 1.466 - ETA: 1:23 - loss: 1.459 - ETA: 1:18 - loss: 1.452 - ETA: 1:12 - loss: 1.452 - ETA: 1:05 - loss: 1.442 - ETA: 58s - loss: 1.513 - ETA: 53s - loss: 1.51 - ETA: 45s - loss: 1.45 - ETA: 39s - loss: 1.39 - ETA: 32s - loss: 1.37 - ETA: 27s - loss: 1.36 - ETA: 21s - loss: 1.33 - ETA: 16s - loss: 1.30 - ETA: 10s - loss: 1.29 - ETA: 5s - loss: 1.2756 - 124s 6s/step - loss: 1.2632 - val_loss: 414.8165
#
# Epoch 00002: val_loss improved from inf to 414.81654, saving model to weights_schrauben_more_data3.h5
# Epoch 3/100
# 22/22 [==============================] - ETA: 53s - loss: 5.09 - ETA: 1:07 - loss: 3.509 - ETA: 1:04 - loss: 2.866 - ETA: 1:04 - loss: 2.442 - ETA: 56s - loss: 2.153 - ETA: 59s - loss: 1.90 - ETA: 56s - loss: 1.78 - ETA: 55s - loss: 1.70 - ETA: 54s - loss: 1.62 - ETA: 53s - loss: 1.51 - ETA: 50s - loss: 1.47 - ETA: 44s - loss: 1.42 - ETA: 41s - loss: 1.39 - ETA: 37s - loss: 1.33 - ETA: 33s - loss: 1.28 - ETA: 28s - loss: 1.24 - ETA: 24s - loss: 1.22 - ETA: 19s - loss: 1.19 - ETA: 14s - loss: 1.18 - ETA: 9s - loss: 1.1751 - ETA: 5s - loss: 1.162 - 112s 5s/step - loss: 1.1570 - val_loss: 1.4397
#
# Epoch 00003: val_loss improved from 414.81654 to 1.43969, saving model to weights_schrauben_more_data3.h5
# Epoch 4/100
# 22/22 [==============================] - ETA: 1:13 - loss: 0.887 - ETA: 1:49 - loss: 0.950 - ETA: 1:52 - loss: 0.847 - ETA: 1:50 - loss: 0.769 - ETA: 1:45 - loss: 0.781 - ETA: 1:33 - loss: 0.770 - ETA: 1:22 - loss: 0.897 - ETA: 1:16 - loss: 0.840 - ETA: 1:09 - loss: 0.815 - ETA: 1:05 - loss: 0.841 - ETA: 1:02 - loss: 1.169 - ETA: 56s - loss: 1.153 - ETA: 50s - loss: 1.14 - ETA: 43s - loss: 1.09 - ETA: 38s - loss: 1.20 - ETA: 33s - loss: 1.16 - ETA: 27s - loss: 1.12 - ETA: 22s - loss: 1.08 - ETA: 16s - loss: 1.06 - ETA: 11s - loss: 1.04 - ETA: 5s - loss: 1.0354 - 120s 5s/step - loss: 1.0144 - val_loss: 1.2578
#
# Epoch 00004: val_loss improved from 1.43969 to 1.25777, saving model to weights_schrauben_more_data3.h5
# Epoch 5/100
# 22/22 [==============================] - ETA: 1:06 - loss: 0.396 - ETA: 1:12 - loss: 1.897 - ETA: 1:07 - loss: 1.590 - ETA: 1:02 - loss: 1.501 - ETA: 1:04 - loss: 1.425 - ETA: 1:09 - loss: 1.360 - ETA: 1:06 - loss: 1.234 - ETA: 58s - loss: 1.175 - ETA: 54s - loss: 1.09 - ETA: 53s - loss: 1.07 - ETA: 49s - loss: 1.01 - ETA: 43s - loss: 0.97 - ETA: 40s - loss: 0.92 - ETA: 35s - loss: 0.89 - ETA: 32s - loss: 0.87 - ETA: 28s - loss: 0.85 - ETA: 24s - loss: 0.84 - ETA: 20s - loss: 0.81 - ETA: 14s - loss: 0.80 - ETA: 9s - loss: 0.7920 - ETA: 5s - loss: 0.879 - 116s 5s/step - loss: 0.8813 - val_loss: 0.9490
#
# Epoch 00005: val_loss improved from 1.25777 to 0.94900, saving model to weights_schrauben_more_data3.h5
# Epoch 6/100
# 22/22 [==============================] - ETA: 1:08 - loss: 0.658 - ETA: 1:20 - loss: 0.585 - ETA: 1:41 - loss: 0.555 - ETA: 1:28 - loss: 0.565 - ETA: 1:23 - loss: 0.605 - ETA: 1:21 - loss: 0.615 - ETA: 1:15 - loss: 0.640 - ETA: 1:08 - loss: 0.654 - ETA: 1:04 - loss: 0.630 - ETA: 1:00 - loss: 0.622 - ETA: 55s - loss: 0.639 - ETA: 50s - loss: 0.63 - ETA: 48s - loss: 0.64 - ETA: 44s - loss: 0.63 - ETA: 38s - loss: 0.67 - ETA: 32s - loss: 0.70 - ETA: 26s - loss: 0.75 - ETA: 21s - loss: 0.74 - ETA: 16s - loss: 0.73 - ETA: 11s - loss: 0.72 - ETA: 5s - loss: 0.7217 - 124s 6s/step - loss: 0.7012 - val_loss: 0.6503
#
# Epoch 00006: val_loss improved from 0.94900 to 0.65034, saving model to weights_schrauben_more_data3.h5
# Epoch 7/100
# 22/22 [==============================] - ETA: 1:03 - loss: 0.748 - ETA: 1:01 - loss: 0.799 - ETA: 1:19 - loss: 0.718 - ETA: 1:16 - loss: 0.614 - ETA: 1:20 - loss: 0.658 - ETA: 1:10 - loss: 0.625 - ETA: 1:07 - loss: 0.621 - ETA: 1:01 - loss: 0.618 - ETA: 55s - loss: 0.582 - ETA: 48s - loss: 0.58 - ETA: 44s - loss: 0.57 - ETA: 39s - loss: 0.56 - ETA: 35s - loss: 0.56 - ETA: 33s - loss: 0.62 - ETA: 30s - loss: 0.62 - ETA: 24s - loss: 0.63 - ETA: 21s - loss: 0.61 - ETA: 17s - loss: 0.60 - ETA: 13s - loss: 0.58 - ETA: 9s - loss: 0.5710 - ETA: 4s - loss: 0.555 - 108s 5s/step - loss: 0.5486 - val_loss: 0.4350
#
# Epoch 00007: val_loss improved from 0.65034 to 0.43501, saving model to weights_schrauben_more_data3.h5
# Epoch 8/100
# 22/22 [==============================] - ETA: 37s - loss: 0.43 - ETA: 1:02 - loss: 0.441 - ETA: 1:20 - loss: 0.377 - ETA: 1:23 - loss: 0.522 - ETA: 1:26 - loss: 0.473 - ETA: 1:17 - loss: 0.457 - ETA: 1:15 - loss: 0.477 - ETA: 1:11 - loss: 0.458 - ETA: 1:07 - loss: 0.528 - ETA: 1:03 - loss: 0.542 - ETA: 56s - loss: 0.589 - ETA: 50s - loss: 0.59 - ETA: 46s - loss: 0.60 - ETA: 40s - loss: 0.60 - ETA: 35s - loss: 0.62 - ETA: 31s - loss: 0.62 - ETA: 26s - loss: 0.62 - ETA: 21s - loss: 0.61 - ETA: 15s - loss: 0.60 - ETA: 10s - loss: 0.61 - ETA: 5s - loss: 0.6091 - 115s 5s/step - loss: 0.5977 - val_loss: 0.5230
#
# Epoch 00008: val_loss did not improve
# Epoch 9/100
# 22/22 [==============================] - ETA: 46s - loss: 1.64 - ETA: 1:22 - loss: 0.973 - ETA: 1:12 - loss: 0.867 - ETA: 1:13 - loss: 0.774 - ETA: 1:11 - loss: 0.752 - ETA: 1:16 - loss: 0.763 - ETA: 1:14 - loss: 0.722 - ETA: 1:14 - loss: 0.686 - ETA: 1:14 - loss: 0.630 - ETA: 1:05 - loss: 0.608 - ETA: 59s - loss: 0.579 - ETA: 53s - loss: 0.56 - ETA: 49s - loss: 0.55 - ETA: 44s - loss: 0.55 - ETA: 38s - loss: 0.58 - ETA: 32s - loss: 0.57 - ETA: 27s - loss: 0.56 - ETA: 22s - loss: 0.55 - ETA: 16s - loss: 0.55 - ETA: 11s - loss: 0.56 - ETA: 5s - loss: 0.5681 - 124s 6s/step - loss: 0.5657 - val_loss: 0.5830
#
# Epoch 00009: val_loss did not improve
# Epoch 10/100
# 22/22 [==============================] - ETA: 43s - loss: 0.76 - ETA: 1:29 - loss: 0.699 - ETA: 1:17 - loss: 0.573 - ETA: 1:24 - loss: 0.530 - ETA: 1:31 - loss: 0.505 - ETA: 1:31 - loss: 0.467 - ETA: 1:24 - loss: 0.434 - ETA: 1:19 - loss: 0.412 - ETA: 1:11 - loss: 0.429 - ETA: 1:05 - loss: 0.512 - ETA: 59s - loss: 1.645 - ETA: 54s - loss: 1.52 - ETA: 48s - loss: 1.49 - ETA: 43s - loss: 1.42 - ETA: 38s - loss: 1.36 - ETA: 32s - loss: 1.30 - ETA: 28s - loss: 1.27 - ETA: 22s - loss: 1.22 - ETA: 16s - loss: 1.20 - ETA: 11s - loss: 1.18 - ETA: 5s - loss: 1.1507 - 123s 6s/step - loss: 1.1551 - val_loss: 0.5413
#
# Epoch 00010: val_loss did not improve
# Epoch 11/100
# 22/22 [==============================] - ETA: 1:58 - loss: 0.242 - ETA: 1:55 - loss: 0.242 - ETA: 1:37 - loss: 0.230 - ETA: 1:38 - loss: 0.422 - ETA: 1:36 - loss: 0.421 - ETA: 1:24 - loss: 0.447 - ETA: 1:28 - loss: 0.407 - ETA: 1:23 - loss: 0.424 - ETA: 1:14 - loss: 0.412 - ETA: 1:08 - loss: 0.417 - ETA: 1:01 - loss: 0.419 - ETA: 58s - loss: 0.420 - ETA: 52s - loss: 0.45 - ETA: 47s - loss: 0.45 - ETA: 39s - loss: 0.47 - ETA: 32s - loss: 0.46 - ETA: 26s - loss: 0.44 - ETA: 21s - loss: 0.44 - ETA: 16s - loss: 0.46 - ETA: 10s - loss: 0.45 - ETA: 5s - loss: 0.4751 - 120s 5s/step - loss: 0.4701 - val_loss: 0.5339
#
# Epoch 00011: val_loss did not improve
# Epoch 12/100
# 22/22 [==============================] - ETA: 1:36 - loss: 0.151 - ETA: 1:30 - loss: 0.617 - ETA: 1:48 - loss: 0.496 - ETA: 1:31 - loss: 0.660 - ETA: 1:31 - loss: 0.639 - ETA: 1:25 - loss: 0.577 - ETA: 1:20 - loss: 0.577 - ETA: 1:10 - loss: 0.587 - ETA: 1:06 - loss: 0.550 - ETA: 1:04 - loss: 0.521 - ETA: 1:00 - loss: 0.569 - ETA: 54s - loss: 0.546 - ETA: 47s - loss: 0.53 - ETA: 42s - loss: 0.51 - ETA: 36s - loss: 0.53 - ETA: 30s - loss: 0.52 - ETA: 25s - loss: 0.52 - ETA: 20s - loss: 0.50 - ETA: 15s - loss: 0.49 - ETA: 10s - loss: 0.49 - ETA: 5s - loss: 0.4916 - 113s 5s/step - loss: 0.4947 - val_loss: 0.4035
#
# Epoch 00012: val_loss improved from 0.43501 to 0.40347, saving model to weights_schrauben_more_data3.h5
# Epoch 13/100
# 22/22 [==============================] - ETA: 40s - loss: 0.33 - ETA: 59s - loss: 0.29 - ETA: 1:16 - loss: 0.301 - ETA: 1:12 - loss: 0.310 - ETA: 1:09 - loss: 0.326 - ETA: 1:04 - loss: 0.324 - ETA: 57s - loss: 0.330 - ETA: 57s - loss: 0.32 - ETA: 54s - loss: 0.32 - ETA: 53s - loss: 0.40 - ETA: 51s - loss: 0.40 - ETA: 49s - loss: 0.43 - ETA: 43s - loss: 0.42 - ETA: 39s - loss: 0.43 - ETA: 34s - loss: 0.46 - ETA: 28s - loss: 0.46 - ETA: 23s - loss: 0.45 - ETA: 19s - loss: 0.45 - ETA: 14s - loss: 0.44 - ETA: 9s - loss: 0.4416 - ETA: 5s - loss: 0.433 - 115s 5s/step - loss: 0.4344 - val_loss: 0.4820
#
# Epoch 00013: val_loss did not improve
# Epoch 14/100
# 22/22 [==============================] - ETA: 1:20 - loss: 0.553 - ETA: 1:43 - loss: 0.409 - ETA: 1:34 - loss: 0.322 - ETA: 1:26 - loss: 0.312 - ETA: 1:25 - loss: 0.312 - ETA: 1:13 - loss: 0.316 - ETA: 1:05 - loss: 0.325 - ETA: 1:02 - loss: 0.342 - ETA: 58s - loss: 0.336 - ETA: 54s - loss: 0.34 - ETA: 52s - loss: 0.35 - ETA: 47s - loss: 0.34 - ETA: 43s - loss: 0.34 - ETA: 40s - loss: 0.34 - ETA: 34s - loss: 0.35 - ETA: 28s - loss: 0.35 - ETA: 24s - loss: 0.37 - ETA: 19s - loss: 0.39 - ETA: 15s - loss: 0.39 - ETA: 10s - loss: 0.39 - ETA: 5s - loss: 0.4025 - 118s 5s/step - loss: 0.4066 - val_loss: 0.6188
#
# Epoch 00014: val_loss did not improve
# Epoch 15/100
# 22/22 [==============================] - ETA: 2:01 - loss: 0.250 - ETA: 2:02 - loss: 0.257 - ETA: 1:37 - loss: 0.375 - ETA: 1:36 - loss: 0.339 - ETA: 1:25 - loss: 0.314 - ETA: 1:25 - loss: 0.307 - ETA: 1:21 - loss: 0.315 - ETA: 1:16 - loss: 0.476 - ETA: 1:10 - loss: 0.482 - ETA: 1:06 - loss: 0.464 - ETA: 57s - loss: 0.477 - ETA: 52s - loss: 0.47 - ETA: 47s - loss: 0.46 - ETA: 42s - loss: 0.45 - ETA: 37s - loss: 0.44 - ETA: 32s - loss: 0.43 - ETA: 26s - loss: 0.41 - ETA: 21s - loss: 0.40 - ETA: 15s - loss: 0.39 - ETA: 10s - loss: 0.42 - ETA: 5s - loss: 0.4258 - 122s 6s/step - loss: 0.4187 - val_loss: 0.5055
#
# Epoch 00015: val_loss did not improve
# Epoch 16/100
# 22/22 [==============================] - ETA: 47s - loss: 0.43 - ETA: 1:03 - loss: 0.328 - ETA: 1:16 - loss: 0.348 - ETA: 1:13 - loss: 0.312 - ETA: 1:09 - loss: 0.319 - ETA: 1:08 - loss: 0.291 - ETA: 1:04 - loss: 0.270 - ETA: 57s - loss: 0.272 - ETA: 56s - loss: 0.26 - ETA: 53s - loss: 0.27 - ETA: 52s - loss: 0.26 - ETA: 48s - loss: 0.27 - ETA: 42s - loss: 0.28 - ETA: 37s - loss: 0.29 - ETA: 32s - loss: 0.29 - ETA: 28s - loss: 0.31 - ETA: 24s - loss: 0.32 - ETA: 19s - loss: 0.32 - ETA: 14s - loss: 0.32 - ETA: 10s - loss: 0.33 - ETA: 4s - loss: 0.3305 - 114s 5s/step - loss: 0.3341 - val_loss: 0.4266
#
# Epoch 00016: val_loss did not improve
# Epoch 17/100
# 22/22 [==============================] - ETA: 2:03 - loss: 0.331 - ETA: 1:29 - loss: 0.283 - ETA: 1:28 - loss: 0.328 - ETA: 1:24 - loss: 0.363 - ETA: 1:24 - loss: 0.375 - ETA: 1:25 - loss: 0.346 - ETA: 1:24 - loss: 0.340 - ETA: 1:21 - loss: 0.341 - ETA: 1:13 - loss: 0.343 - ETA: 1:07 - loss: 0.341 - ETA: 1:01 - loss: 0.341 - ETA: 55s - loss: 0.326 - ETA: 49s - loss: 0.35 - ETA: 44s - loss: 0.37 - ETA: 40s - loss: 0.37 - ETA: 35s - loss: 0.36 - ETA: 29s - loss: 0.35 - ETA: 23s - loss: 0.36 - ETA: 17s - loss: 0.40 - ETA: 11s - loss: 0.40 - ETA: 5s - loss: 0.3919 - 127s 6s/step - loss: 0.3848 - val_loss: 0.4492
#
# Epoch 00017: val_loss did not improve
# Epoch 18/100
# 22/22 [==============================] - ETA: 1:45 - loss: 0.294 - ETA: 1:26 - loss: 0.314 - ETA: 1:37 - loss: 0.331 - ETA: 1:36 - loss: 0.320 - ETA: 1:22 - loss: 0.278 - ETA: 1:19 - loss: 0.299 - ETA: 1:12 - loss: 0.274 - ETA: 1:12 - loss: 0.357 - ETA: 1:09 - loss: 0.339 - ETA: 1:03 - loss: 0.336 - ETA: 58s - loss: 0.318 - ETA: 53s - loss: 0.31 - ETA: 47s - loss: 0.30 - ETA: 42s - loss: 0.29 - ETA: 36s - loss: 0.30 - ETA: 31s - loss: 0.32 - ETA: 25s - loss: 0.32 - ETA: 21s - loss: 0.34 - ETA: 16s - loss: 0.33 - ETA: 10s - loss: 0.32 - ETA: 5s - loss: 0.3303 - 124s 6s/step - loss: 0.3231 - val_loss: 0.3656
#
# Epoch 00018: val_loss improved from 0.40347 to 0.36564, saving model to weights_schrauben_more_data3.h5
# Epoch 19/100
# 22/22 [==============================] - ETA: 24s - loss: 0.13 - ETA: 1:05 - loss: 0.298 - ETA: 1:23 - loss: 0.324 - ETA: 1:13 - loss: 0.326 - ETA: 1:18 - loss: 0.302 - ETA: 1:16 - loss: 0.293 - ETA: 1:14 - loss: 0.287 - ETA: 1:07 - loss: 0.274 - ETA: 1:04 - loss: 0.292 - ETA: 58s - loss: 0.309 - ETA: 54s - loss: 0.31 - ETA: 50s - loss: 0.33 - ETA: 44s - loss: 0.34 - ETA: 38s - loss: 0.35 - ETA: 34s - loss: 0.34 - ETA: 29s - loss: 0.33 - ETA: 24s - loss: 0.33 - ETA: 19s - loss: 0.32 - ETA: 14s - loss: 0.32 - ETA: 9s - loss: 0.3426 - ETA: 5s - loss: 0.340 - 112s 5s/step - loss: 0.3337 - val_loss: 0.3680
#
# Epoch 00019: val_loss did not improve
# Epoch 20/100
# 22/22 [==============================] - ETA: 1:16 - loss: 0.251 - ETA: 1:42 - loss: 0.256 - ETA: 1:34 - loss: 0.326 - ETA: 1:27 - loss: 0.303 - ETA: 1:27 - loss: 0.282 - ETA: 1:30 - loss: 0.281 - ETA: 1:27 - loss: 0.303 - ETA: 1:19 - loss: 0.306 - ETA: 1:17 - loss: 0.294 - ETA: 1:12 - loss: 0.351 - ETA: 1:08 - loss: 0.335 - ETA: 1:02 - loss: 0.338 - ETA: 56s - loss: 0.332 - ETA: 50s - loss: 0.32 - ETA: 43s - loss: 0.30 - ETA: 38s - loss: 0.32 - ETA: 32s - loss: 0.33 - ETA: 24s - loss: 0.32 - ETA: 18s - loss: 0.32 - ETA: 12s - loss: 0.31 - ETA: 6s - loss: 0.3311 - 136s 6s/step - loss: 0.3331 - val_loss: 0.4820
#
# Epoch 00020: val_loss did not improve
# Epoch 21/100
# 22/22 [==============================] - ETA: 13s - loss: 0.16 - ETA: 1:14 - loss: 0.469 - ETA: 1:05 - loss: 0.529 - ETA: 1:11 - loss: 0.439 - ETA: 1:20 - loss: 0.406 - ETA: 1:14 - loss: 0.402 - ETA: 1:13 - loss: 0.373 - ETA: 1:09 - loss: 0.381 - ETA: 1:06 - loss: 0.366 - ETA: 1:03 - loss: 0.351 - ETA: 58s - loss: 0.337 - ETA: 53s - loss: 0.33 - ETA: 48s - loss: 0.33 - ETA: 42s - loss: 0.34 - ETA: 36s - loss: 0.34 - ETA: 30s - loss: 0.33 - ETA: 25s - loss: 0.33 - ETA: 20s - loss: 0.33 - ETA: 15s - loss: 0.33 - ETA: 10s - loss: 0.33 - ETA: 5s - loss: 0.3282 - 116s 5s/step - loss: 0.3230 - val_loss: 0.5174
#
# Epoch 00021: val_loss did not improve
# Epoch 22/100
# 22/22 [==============================] - ETA: 31s - loss: 0.34 - ETA: 1:33 - loss: 0.248 - ETA: 1:51 - loss: 0.211 - ETA: 1:37 - loss: 0.189 - ETA: 1:37 - loss: 0.183 - ETA: 1:30 - loss: 0.201 - ETA: 1:22 - loss: 0.197 - ETA: 1:18 - loss: 0.213 - ETA: 1:11 - loss: 0.205 - ETA: 1:07 - loss: 0.203 - ETA: 1:00 - loss: 0.204 - ETA: 54s - loss: 0.361 - ETA: 49s - loss: 0.36 - ETA: 42s - loss: 0.35 - ETA: 37s - loss: 0.35 - ETA: 31s - loss: 0.34 - ETA: 26s - loss: 0.34 - ETA: 21s - loss: 0.34 - ETA: 16s - loss: 0.33 - ETA: 10s - loss: 0.34 - ETA: 5s - loss: 0.3420 - 116s 5s/step - loss: 0.3396 - val_loss: 0.3890
#
# Epoch 00022: val_loss did not improve
# Epoch 23/100
# 22/22 [==============================] - ETA: 3s - loss: 0.402 - ETA: 1:09 - loss: 0.403 - ETA: 1:15 - loss: 0.394 - ETA: 1:13 - loss: 0.374 - ETA: 1:18 - loss: 0.359 - ETA: 1:17 - loss: 0.358 - ETA: 1:11 - loss: 0.380 - ETA: 1:13 - loss: 0.354 - ETA: 1:09 - loss: 0.329 - ETA: 1:07 - loss: 0.311 - ETA: 1:02 - loss: 0.306 - ETA: 56s - loss: 0.314 - ETA: 50s - loss: 0.30 - ETA: 44s - loss: 0.29 - ETA: 38s - loss: 0.28 - ETA: 32s - loss: 0.27 - ETA: 27s - loss: 0.27 - ETA: 21s - loss: 0.27 - ETA: 16s - loss: 0.27 - ETA: 10s - loss: 0.26 - ETA: 5s - loss: 0.2849 - 121s 6s/step - loss: 0.2873 - val_loss: 0.4985
#
# Epoch 00023: val_loss did not improve
# Epoch 24/100
# 22/22 [==============================] - ETA: 1:10 - loss: 0.323 - ETA: 1:08 - loss: 0.225 - ETA: 1:31 - loss: 0.204 - ETA: 1:20 - loss: 0.198 - ETA: 1:21 - loss: 0.193 - ETA: 1:17 - loss: 0.181 - ETA: 1:17 - loss: 0.181 - ETA: 1:14 - loss: 0.177 - ETA: 1:14 - loss: 0.182 - ETA: 1:08 - loss: 0.187 - ETA: 1:01 - loss: 0.184 - ETA: 58s - loss: 0.186 - ETA: 51s - loss: 0.18 - ETA: 47s - loss: 0.20 - ETA: 40s - loss: 0.22 - ETA: 34s - loss: 0.22 - ETA: 28s - loss: 0.22 - ETA: 22s - loss: 0.23 - ETA: 17s - loss: 0.23 - ETA: 11s - loss: 0.23 - ETA: 5s - loss: 0.2356 - 125s 6s/step - loss: 0.2368 - val_loss: 0.3537
#
# Epoch 00024: val_loss improved from 0.36564 to 0.35372, saving model to weights_schrauben_more_data3.h5
# Epoch 25/100
# 22/22 [==============================] - ETA: 1:21 - loss: 0.141 - ETA: 1:47 - loss: 0.202 - ETA: 2:04 - loss: 0.168 - ETA: 1:49 - loss: 0.209 - ETA: 1:46 - loss: 0.222 - ETA: 1:38 - loss: 0.225 - ETA: 1:27 - loss: 0.216 - ETA: 1:24 - loss: 0.225 - ETA: 1:14 - loss: 0.236 - ETA: 1:06 - loss: 0.232 - ETA: 57s - loss: 0.227 - ETA: 53s - loss: 0.22 - ETA: 48s - loss: 0.27 - ETA: 42s - loss: 0.27 - ETA: 38s - loss: 0.26 - ETA: 32s - loss: 0.30 - ETA: 26s - loss: 0.30 - ETA: 20s - loss: 0.29 - ETA: 15s - loss: 0.29 - ETA: 10s - loss: 0.28 - ETA: 5s - loss: 0.2804 - 118s 5s/step - loss: 0.2889 - val_loss: 0.4913
#
# Epoch 00025: val_loss did not improve
# Epoch 26/100
# 22/22 [==============================] - ETA: 2:00 - loss: 0.355 - ETA: 1:43 - loss: 0.275 - ETA: 1:40 - loss: 0.335 - ETA: 1:33 - loss: 0.322 - ETA: 1:35 - loss: 0.302 - ETA: 1:23 - loss: 0.283 - ETA: 1:18 - loss: 0.287 - ETA: 1:10 - loss: 0.277 - ETA: 1:06 - loss: 0.273 - ETA: 57s - loss: 0.268 - ETA: 52s - loss: 0.25 - ETA: 48s - loss: 0.36 - ETA: 42s - loss: 0.36 - ETA: 38s - loss: 0.34 - ETA: 33s - loss: 0.33 - ETA: 29s - loss: 0.33 - ETA: 24s - loss: 0.33 - ETA: 18s - loss: 0.32 - ETA: 14s - loss: 0.31 - ETA: 9s - loss: 0.3076 - ETA: 4s - loss: 0.300 - 111s 5s/step - loss: 0.2941 - val_loss: 0.3226
#
# Epoch 00026: val_loss improved from 0.35372 to 0.32264, saving model to weights_schrauben_more_data3.h5
# Epoch 27/100
# 22/22 [==============================] - ETA: 1:37 - loss: 0.152 - ETA: 1:53 - loss: 0.181 - ETA: 1:40 - loss: 0.186 - ETA: 1:29 - loss: 0.193 - ETA: 1:23 - loss: 0.183 - ETA: 1:13 - loss: 0.178 - ETA: 1:13 - loss: 0.166 - ETA: 1:10 - loss: 0.170 - ETA: 1:10 - loss: 0.197 - ETA: 1:06 - loss: 0.194 - ETA: 59s - loss: 0.213 - ETA: 53s - loss: 0.21 - ETA: 47s - loss: 0.22 - ETA: 42s - loss: 0.23 - ETA: 36s - loss: 0.22 - ETA: 32s - loss: 0.24 - ETA: 27s - loss: 0.23 - ETA: 22s - loss: 0.24 - ETA: 16s - loss: 0.25 - ETA: 11s - loss: 0.24 - ETA: 5s - loss: 0.2459 - 125s 6s/step - loss: 0.2445 - val_loss: 0.4440
#
# Epoch 00027: val_loss did not improve
# Epoch 28/100
# 22/22 [==============================] - ETA: 36s - loss: 0.16 - ETA: 1:14 - loss: 0.160 - ETA: 1:14 - loss: 0.156 - ETA: 1:29 - loss: 0.146 - ETA: 1:24 - loss: 0.164 - ETA: 1:20 - loss: 0.160 - ETA: 1:18 - loss: 0.178 - ETA: 1:10 - loss: 0.175 - ETA: 1:10 - loss: 0.169 - ETA: 1:04 - loss: 0.196 - ETA: 1:00 - loss: 0.193 - ETA: 56s - loss: 0.194 - ETA: 49s - loss: 0.19 - ETA: 44s - loss: 0.19 - ETA: 38s - loss: 0.18 - ETA: 32s - loss: 0.18 - ETA: 26s - loss: 0.17 - ETA: 21s - loss: 0.19 - ETA: 16s - loss: 0.19 - ETA: 10s - loss: 0.20 - ETA: 5s - loss: 0.1988 - 120s 5s/step - loss: 0.2028 - val_loss: 0.3564
#
# Epoch 00028: val_loss did not improve
# Epoch 29/100
# 22/22 [==============================] - ETA: 49s - loss: 0.17 - ETA: 1:20 - loss: 0.332 - ETA: 1:19 - loss: 0.297 - ETA: 1:20 - loss: 0.274 - ETA: 1:14 - loss: 0.271 - ETA: 1:08 - loss: 0.266 - ETA: 1:11 - loss: 0.257 - ETA: 1:08 - loss: 0.265 - ETA: 1:05 - loss: 0.243 - ETA: 1:00 - loss: 0.228 - ETA: 55s - loss: 0.221 - ETA: 50s - loss: 0.21 - ETA: 46s - loss: 0.26 - ETA: 40s - loss: 0.25 - ETA: 36s - loss: 0.25 - ETA: 31s - loss: 0.24 - ETA: 26s - loss: 0.24 - ETA: 21s - loss: 0.24 - ETA: 15s - loss: 0.24 - ETA: 10s - loss: 0.24 - ETA: 5s - loss: 0.2382 - 119s 5s/step - loss: 0.2362 - val_loss: 0.3351
#
# Epoch 00029: val_loss did not improve
# Epoch 30/100
# 22/22 [==============================] - ETA: 1:46 - loss: 0.217 - ETA: 1:34 - loss: 0.176 - ETA: 1:18 - loss: 0.159 - ETA: 1:19 - loss: 0.209 - ETA: 1:18 - loss: 0.219 - ETA: 1:15 - loss: 0.381 - ETA: 1:14 - loss: 0.364 - ETA: 1:15 - loss: 0.351 - ETA: 1:08 - loss: 0.325 - ETA: 1:02 - loss: 0.304 - ETA: 56s - loss: 0.287 - ETA: 52s - loss: 0.28 - ETA: 46s - loss: 0.27 - ETA: 40s - loss: 0.27 - ETA: 35s - loss: 0.27 - ETA: 30s - loss: 0.26 - ETA: 25s - loss: 0.25 - ETA: 20s - loss: 0.24 - ETA: 15s - loss: 0.24 - ETA: 10s - loss: 0.24 - ETA: 5s - loss: 0.2515 - 116s 5s/step - loss: 0.2497 - val_loss: 0.3580
#
# Epoch 00030: val_loss did not improve
# Epoch 31/100
# 22/22 [==============================] - ETA: 2:23 - loss: 0.189 - ETA: 1:57 - loss: 0.139 - ETA: 1:56 - loss: 0.150 - ETA: 1:46 - loss: 0.164 - ETA: 1:32 - loss: 0.159 - ETA: 1:26 - loss: 0.178 - ETA: 1:15 - loss: 0.169 - ETA: 1:08 - loss: 0.156 - ETA: 1:04 - loss: 0.172 - ETA: 1:01 - loss: 0.172 - ETA: 56s - loss: 0.163 - ETA: 52s - loss: 0.15 - ETA: 47s - loss: 0.16 - ETA: 40s - loss: 0.16 - ETA: 35s - loss: 0.16 - ETA: 30s - loss: 0.16 - ETA: 25s - loss: 0.17 - ETA: 21s - loss: 0.18 - ETA: 16s - loss: 0.18 - ETA: 10s - loss: 0.17 - ETA: 5s - loss: 0.1760 - 123s 6s/step - loss: 0.1781 - val_loss: 0.3444
#
# Epoch 00031: val_loss did not improve
# Epoch 32/100
# 22/22 [==============================] - ETA: 56s - loss: 0.14 - ETA: 1:14 - loss: 0.159 - ETA: 1:15 - loss: 0.198 - ETA: 1:25 - loss: 0.181 - ETA: 1:30 - loss: 0.185 - ETA: 1:26 - loss: 0.172 - ETA: 1:19 - loss: 0.184 - ETA: 1:15 - loss: 0.177 - ETA: 1:08 - loss: 0.185 - ETA: 1:03 - loss: 0.189 - ETA: 56s - loss: 0.181 - ETA: 52s - loss: 0.17 - ETA: 47s - loss: 0.18 - ETA: 42s - loss: 0.20 - ETA: 36s - loss: 0.20 - ETA: 30s - loss: 0.19 - ETA: 25s - loss: 0.19 - ETA: 20s - loss: 0.20 - ETA: 16s - loss: 0.20 - ETA: 11s - loss: 0.20 - ETA: 5s - loss: 0.2062 - 128s 6s/step - loss: 0.2253 - val_loss: 0.3379
#
# Epoch 00032: val_loss did not improve
# Epoch 33/100
# 22/22 [==============================] - ETA: 53s - loss: 0.24 - ETA: 1:27 - loss: 0.230 - ETA: 1:29 - loss: 0.202 - ETA: 1:24 - loss: 0.205 - ETA: 1:16 - loss: 0.209 - ETA: 1:20 - loss: 0.247 - ETA: 1:13 - loss: 0.264 - ETA: 1:08 - loss: 0.248 - ETA: 1:06 - loss: 0.243 - ETA: 1:00 - loss: 0.238 - ETA: 55s - loss: 0.228 - ETA: 49s - loss: 0.22 - ETA: 47s - loss: 0.22 - ETA: 41s - loss: 0.22 - ETA: 35s - loss: 0.21 - ETA: 30s - loss: 0.20 - ETA: 26s - loss: 0.20 - ETA: 21s - loss: 0.19 - ETA: 15s - loss: 0.19 - ETA: 10s - loss: 0.19 - ETA: 5s - loss: 0.1974 - 118s 5s/step - loss: 0.2039 - val_loss: 0.3943
#
# Epoch 00033: val_loss did not improve
# Epoch 34/100
# 22/22 [==============================] - ETA: 1:26 - loss: 0.382 - ETA: 1:31 - loss: 0.243 - ETA: 1:21 - loss: 0.228 - ETA: 1:29 - loss: 0.244 - ETA: 1:28 - loss: 0.245 - ETA: 1:27 - loss: 0.253 - ETA: 1:23 - loss: 0.244 - ETA: 1:16 - loss: 0.277 - ETA: 1:16 - loss: 0.286 - ETA: 1:09 - loss: 0.268 - ETA: 1:00 - loss: 0.260 - ETA: 53s - loss: 0.251 - ETA: 47s - loss: 0.24 - ETA: 43s - loss: 0.23 - ETA: 39s - loss: 0.22 - ETA: 34s - loss: 0.22 - ETA: 28s - loss: 0.22 - ETA: 22s - loss: 0.22 - ETA: 16s - loss: 0.22 - ETA: 11s - loss: 0.22 - ETA: 5s - loss: 0.2199 - 125s 6s/step - loss: 0.2146 - val_loss: 0.3123
#
# Epoch 00034: val_loss improved from 0.32264 to 0.31228, saving model to weights_schrauben_more_data3.h5
# Epoch 35/100
# 22/22 [==============================] - ETA: 3s - loss: 0.126 - ETA: 1:26 - loss: 0.104 - ETA: 1:27 - loss: 0.169 - ETA: 1:24 - loss: 0.176 - ETA: 1:16 - loss: 0.163 - ETA: 1:09 - loss: 0.157 - ETA: 1:08 - loss: 0.148 - ETA: 1:08 - loss: 0.184 - ETA: 1:05 - loss: 0.186 - ETA: 59s - loss: 0.188 - ETA: 51s - loss: 0.19 - ETA: 47s - loss: 0.19 - ETA: 41s - loss: 0.18 - ETA: 37s - loss: 0.18 - ETA: 32s - loss: 0.18 - ETA: 28s - loss: 0.21 - ETA: 24s - loss: 0.21 - ETA: 19s - loss: 0.21 - ETA: 15s - loss: 0.21 - ETA: 10s - loss: 0.21 - ETA: 5s - loss: 0.2143 - 115s 5s/step - loss: 0.2199 - val_loss: 0.4055
#
# Epoch 00035: val_loss did not improve
# Epoch 36/100
# 22/22 [==============================] - ETA: 1:49 - loss: 0.198 - ETA: 1:26 - loss: 0.239 - ETA: 1:11 - loss: 0.234 - ETA: 1:19 - loss: 0.213 - ETA: 1:20 - loss: 0.197 - ETA: 1:22 - loss: 0.187 - ETA: 1:18 - loss: 0.184 - ETA: 1:11 - loss: 0.200 - ETA: 1:09 - loss: 0.192 - ETA: 1:07 - loss: 0.185 - ETA: 1:01 - loss: 0.187 - ETA: 57s - loss: 0.198 - ETA: 51s - loss: 0.20 - ETA: 45s - loss: 0.19 - ETA: 40s - loss: 0.19 - ETA: 34s - loss: 0.18 - ETA: 28s - loss: 0.18 - ETA: 22s - loss: 0.18 - ETA: 16s - loss: 0.18 - ETA: 11s - loss: 0.18 - ETA: 5s - loss: 0.1797 - 128s 6s/step - loss: 0.1836 - val_loss: 0.3095
#
# Epoch 00036: val_loss improved from 0.31228 to 0.30954, saving model to weights_schrauben_more_data3.h5
# Epoch 37/100
# 22/22 [==============================] - ETA: 1:17 - loss: 0.318 - ETA: 1:10 - loss: 0.294 - ETA: 1:12 - loss: 0.279 - ETA: 1:26 - loss: 0.276 - ETA: 1:21 - loss: 0.271 - ETA: 1:15 - loss: 0.243 - ETA: 1:15 - loss: 0.251 - ETA: 1:09 - loss: 0.240 - ETA: 1:08 - loss: 0.262 - ETA: 1:04 - loss: 0.263 - ETA: 1:00 - loss: 0.252 - ETA: 55s - loss: 0.244 - ETA: 49s - loss: 0.23 - ETA: 43s - loss: 0.23 - ETA: 38s - loss: 0.22 - ETA: 32s - loss: 0.22 - ETA: 28s - loss: 0.21 - ETA: 22s - loss: 0.21 - ETA: 16s - loss: 0.20 - ETA: 11s - loss: 0.20 - ETA: 5s - loss: 0.2050 - 127s 6s/step - loss: 0.2081 - val_loss: 0.3837
#
# Epoch 00037: val_loss did not improve
# Epoch 38/100
# 22/22 [==============================] - ETA: 2:01 - loss: 0.111 - ETA: 1:21 - loss: 0.115 - ETA: 1:14 - loss: 0.119 - ETA: 1:18 - loss: 0.121 - ETA: 1:08 - loss: 0.120 - ETA: 1:11 - loss: 0.128 - ETA: 1:11 - loss: 0.165 - ETA: 1:09 - loss: 0.173 - ETA: 1:06 - loss: 0.190 - ETA: 1:03 - loss: 0.190 - ETA: 58s - loss: 0.183 - ETA: 53s - loss: 0.18 - ETA: 48s - loss: 0.17 - ETA: 43s - loss: 0.17 - ETA: 38s - loss: 0.17 - ETA: 32s - loss: 0.17 - ETA: 27s - loss: 0.16 - ETA: 21s - loss: 0.16 - ETA: 16s - loss: 0.16 - ETA: 10s - loss: 0.16 - ETA: 5s - loss: 0.1777 - 115s 5s/step - loss: 0.1848 - val_loss: 0.3634
#
# Epoch 00038: val_loss did not improve
# Epoch 39/100
# 22/22 [==============================] - ETA: 1:02 - loss: 1.077 - ETA: 1:28 - loss: 0.586 - ETA: 1:15 - loss: 0.427 - ETA: 1:19 - loss: 0.684 - ETA: 1:20 - loss: 0.598 - ETA: 1:13 - loss: 0.520 - ETA: 1:09 - loss: 0.483 - ETA: 1:05 - loss: 0.436 - ETA: 57s - loss: 0.404 - ETA: 53s - loss: 0.37 - ETA: 53s - loss: 0.36 - ETA: 50s - loss: 0.34 - ETA: 44s - loss: 0.32 - ETA: 40s - loss: 0.33 - ETA: 35s - loss: 0.32 - ETA: 31s - loss: 0.31 - ETA: 26s - loss: 0.31 - ETA: 22s - loss: 0.30 - ETA: 16s - loss: 0.29 - ETA: 10s - loss: 0.29 - ETA: 5s - loss: 0.2833 - 122s 6s/step - loss: 0.2758 - val_loss: 0.3466
#
# Epoch 00039: val_loss did not improve
# Epoch 40/100
# 22/22 [==============================] - ETA: 1:48 - loss: 0.150 - ETA: 1:15 - loss: 0.116 - ETA: 1:09 - loss: 0.142 - ETA: 57s - loss: 0.135 - ETA: 1:01 - loss: 0.133 - ETA: 1:00 - loss: 0.134 - ETA: 1:01 - loss: 0.151 - ETA: 1:02 - loss: 0.164 - ETA: 1:01 - loss: 0.161 - ETA: 59s - loss: 0.158 - ETA: 53s - loss: 0.15 - ETA: 47s - loss: 0.15 - ETA: 43s - loss: 0.15 - ETA: 38s - loss: 0.15 - ETA: 33s - loss: 0.15 - ETA: 28s - loss: 0.15 - ETA: 24s - loss: 0.14 - ETA: 19s - loss: 0.14 - ETA: 14s - loss: 0.14 - ETA: 9s - loss: 0.1469 - ETA: 4s - loss: 0.144 - 112s 5s/step - loss: 0.1456 - val_loss: 0.3482
#
# Epoch 00040: val_loss did not improve
# Epoch 41/100
# 22/22 [==============================] - ETA: 1:13 - loss: 0.075 - ETA: 2:19 - loss: 0.259 - ETA: 2:05 - loss: 0.231 - ETA: 2:00 - loss: 0.248 - ETA: 1:49 - loss: 0.279 - ETA: 1:36 - loss: 0.299 - ETA: 1:34 - loss: 0.281 - ETA: 1:23 - loss: 0.272 - ETA: 1:18 - loss: 0.257 - ETA: 1:12 - loss: 0.246 - ETA: 1:06 - loss: 0.232 - ETA: 59s - loss: 0.228 - ETA: 52s - loss: 0.21 - ETA: 47s - loss: 0.21 - ETA: 41s - loss: 0.20 - ETA: 35s - loss: 0.20 - ETA: 29s - loss: 0.22 - ETA: 23s - loss: 0.22 - ETA: 17s - loss: 0.22 - ETA: 11s - loss: 0.22 - ETA: 5s - loss: 0.2253 - 128s 6s/step - loss: 0.2208 - val_loss: 0.3066
#
# Epoch 00041: val_loss improved from 0.30954 to 0.30664, saving model to weights_schrauben_more_data3.h5
# Epoch 42/100
# 22/22 [==============================] - ETA: 35s - loss: 0.13 - ETA: 1:15 - loss: 0.123 - ETA: 1:07 - loss: 0.158 - ETA: 1:00 - loss: 0.156 - ETA: 1:07 - loss: 0.144 - ETA: 1:10 - loss: 0.183 - ETA: 1:05 - loss: 0.182 - ETA: 1:02 - loss: 0.171 - ETA: 1:02 - loss: 0.160 - ETA: 57s - loss: 0.157 - ETA: 52s - loss: 0.15 - ETA: 47s - loss: 0.15 - ETA: 44s - loss: 0.17 - ETA: 38s - loss: 0.17 - ETA: 34s - loss: 0.17 - ETA: 29s - loss: 0.17 - ETA: 25s - loss: 0.17 - ETA: 20s - loss: 0.17 - ETA: 15s - loss: 0.16 - ETA: 10s - loss: 0.16 - ETA: 5s - loss: 0.1647 - 120s 5s/step - loss: 0.1651 - val_loss: 0.2570
#
# Epoch 00042: val_loss improved from 0.30664 to 0.25705, saving model to weights_schrauben_more_data3.h5
# Epoch 43/100
# 22/22 [==============================] - ETA: 26s - loss: 0.12 - ETA: 1:10 - loss: 0.116 - ETA: 1:30 - loss: 0.128 - ETA: 1:25 - loss: 0.108 - ETA: 1:19 - loss: 0.118 - ETA: 1:19 - loss: 0.120 - ETA: 1:13 - loss: 0.118 - ETA: 1:10 - loss: 0.126 - ETA: 1:05 - loss: 0.132 - ETA: 1:01 - loss: 0.145 - ETA: 59s - loss: 0.145 - ETA: 54s - loss: 0.14 - ETA: 49s - loss: 0.15 - ETA: 43s - loss: 0.15 - ETA: 37s - loss: 0.15 - ETA: 31s - loss: 0.14 - ETA: 26s - loss: 0.14 - ETA: 20s - loss: 0.14 - ETA: 15s - loss: 0.14 - ETA: 9s - loss: 0.1457 - ETA: 5s - loss: 0.151 - 115s 5s/step - loss: 0.1519 - val_loss: 0.2898
#
# Epoch 00043: val_loss did not improve
# Epoch 44/100
# 22/22 [==============================] - ETA: 1:19 - loss: 0.093 - ETA: 1:21 - loss: 0.086 - ETA: 1:16 - loss: 0.177 - ETA: 1:32 - loss: 0.172 - ETA: 1:33 - loss: 0.183 - ETA: 1:32 - loss: 0.170 - ETA: 1:24 - loss: 0.171 - ETA: 1:18 - loss: 0.160 - ETA: 1:15 - loss: 0.151 - ETA: 1:09 - loss: 0.143 - ETA: 1:03 - loss: 0.141 - ETA: 56s - loss: 0.142 - ETA: 51s - loss: 0.16 - ETA: 46s - loss: 0.16 - ETA: 40s - loss: 0.15 - ETA: 35s - loss: 0.16 - ETA: 30s - loss: 0.15 - ETA: 24s - loss: 0.16 - ETA: 18s - loss: 0.15 - ETA: 12s - loss: 0.16 - ETA: 6s - loss: 0.1619 - 134s 6s/step - loss: 0.1628 - val_loss: 0.3079
#
# Epoch 00044: val_loss did not improve
# Epoch 45/100
# 22/22 [==============================] - ETA: 36s - loss: 0.14 - ETA: 1:07 - loss: 0.231 - ETA: 1:18 - loss: 0.253 - ETA: 1:23 - loss: 0.368 - ETA: 1:19 - loss: 0.317 - ETA: 1:17 - loss: 0.283 - ETA: 1:10 - loss: 0.258 - ETA: 1:03 - loss: 0.237 - ETA: 59s - loss: 0.230 - ETA: 53s - loss: 0.27 - ETA: 50s - loss: 0.26 - ETA: 45s - loss: 0.24 - ETA: 40s - loss: 0.23 - ETA: 36s - loss: 0.23 - ETA: 32s - loss: 0.22 - ETA: 27s - loss: 0.21 - ETA: 23s - loss: 0.20 - ETA: 18s - loss: 0.20 - ETA: 14s - loss: 0.20 - ETA: 9s - loss: 0.2010 - ETA: 4s - loss: 0.196 - 110s 5s/step - loss: 0.1931 - val_loss: 0.3434
#
# Epoch 00045: val_loss did not improve
# Epoch 46/100
# 22/22 [==============================] - ETA: 36s - loss: 0.14 - ETA: 1:11 - loss: 0.119 - ETA: 1:30 - loss: 0.140 - ETA: 1:27 - loss: 0.133 - ETA: 1:29 - loss: 0.126 - ETA: 1:27 - loss: 0.125 - ETA: 1:20 - loss: 0.124 - ETA: 1:15 - loss: 0.117 - ETA: 1:08 - loss: 0.116 - ETA: 1:04 - loss: 0.120 - ETA: 59s - loss: 0.136 - ETA: 51s - loss: 0.14 - ETA: 47s - loss: 0.15 - ETA: 42s - loss: 0.14 - ETA: 36s - loss: 0.14 - ETA: 31s - loss: 0.15 - ETA: 26s - loss: 0.16 - ETA: 20s - loss: 0.16 - ETA: 15s - loss: 0.15 - ETA: 10s - loss: 0.16 - ETA: 5s - loss: 0.1586 - 113s 5s/step - loss: 0.1565 - val_loss: 0.2698
#
# Epoch 00046: val_loss did not improve
# Epoch 47/100
# 22/22 [==============================] - ETA: 1:05 - loss: 0.223 - ETA: 1:28 - loss: 0.389 - ETA: 1:17 - loss: 0.291 - ETA: 1:15 - loss: 0.251 - ETA: 1:24 - loss: 0.213 - ETA: 1:23 - loss: 0.200 - ETA: 1:21 - loss: 0.184 - ETA: 1:18 - loss: 0.180 - ETA: 1:10 - loss: 0.172 - ETA: 1:07 - loss: 0.178 - ETA: 1:00 - loss: 0.175 - ETA: 53s - loss: 0.188 - ETA: 51s - loss: 0.18 - ETA: 44s - loss: 0.17 - ETA: 40s - loss: 0.17 - ETA: 35s - loss: 0.16 - ETA: 28s - loss: 0.17 - ETA: 23s - loss: 0.16 - ETA: 17s - loss: 0.16 - ETA: 11s - loss: 0.16 - ETA: 5s - loss: 0.1718 - 130s 6s/step - loss: 0.1679 - val_loss: 0.3450
#
# Epoch 00047: val_loss did not improve
# Epoch 48/100
# 22/22 [==============================] - ETA: 1:14 - loss: 0.082 - ETA: 2:07 - loss: 0.409 - ETA: 1:59 - loss: 0.383 - ETA: 1:43 - loss: 0.310 - ETA: 1:38 - loss: 0.277 - ETA: 1:28 - loss: 0.247 - ETA: 1:28 - loss: 0.229 - ETA: 1:18 - loss: 0.218 - ETA: 1:08 - loss: 0.234 - ETA: 1:03 - loss: 0.241 - ETA: 59s - loss: 0.232 - ETA: 52s - loss: 0.22 - ETA: 48s - loss: 0.21 - ETA: 43s - loss: 0.21 - ETA: 38s - loss: 0.20 - ETA: 32s - loss: 0.19 - ETA: 27s - loss: 0.19 - ETA: 21s - loss: 0.19 - ETA: 15s - loss: 0.18 - ETA: 10s - loss: 0.18 - ETA: 5s - loss: 0.1762 - 116s 5s/step - loss: 0.1752 - val_loss: 0.3515
#
# Epoch 00048: val_loss did not improve
# Epoch 49/100
# 22/22 [==============================] - ETA: 2:03 - loss: 0.701 - ETA: 1:25 - loss: 0.443 - ETA: 1:21 - loss: 0.323 - ETA: 1:19 - loss: 0.264 - ETA: 1:12 - loss: 0.309 - ETA: 1:12 - loss: 0.283 - ETA: 1:01 - loss: 0.256 - ETA: 58s - loss: 0.239 - ETA: 55s - loss: 0.22 - ETA: 54s - loss: 0.20 - ETA: 50s - loss: 0.19 - ETA: 45s - loss: 0.18 - ETA: 42s - loss: 0.18 - ETA: 39s - loss: 0.18 - ETA: 36s - loss: 0.18 - ETA: 32s - loss: 0.17 - ETA: 26s - loss: 0.17 - ETA: 21s - loss: 0.18 - ETA: 16s - loss: 0.18 - ETA: 10s - loss: 0.18 - ETA: 5s - loss: 0.1811 - 129s 6s/step - loss: 0.1808 - val_loss: 0.3382
#
# Epoch 00049: val_loss did not improve
# Epoch 50/100
# 22/22 [==============================] - ETA: 1:28 - loss: 0.084 - ETA: 1:24 - loss: 0.112 - ETA: 1:39 - loss: 0.114 - ETA: 1:26 - loss: 0.118 - ETA: 1:19 - loss: 0.117 - ETA: 1:19 - loss: 0.120 - ETA: 1:21 - loss: 0.141 - ETA: 1:13 - loss: 0.143 - ETA: 1:09 - loss: 0.145 - ETA: 1:03 - loss: 0.140 - ETA: 1:01 - loss: 0.153 - ETA: 57s - loss: 0.150 - ETA: 52s - loss: 0.14 - ETA: 46s - loss: 0.14 - ETA: 40s - loss: 0.15 - ETA: 33s - loss: 0.14 - ETA: 28s - loss: 0.14 - ETA: 22s - loss: 0.16 - ETA: 17s - loss: 0.15 - ETA: 11s - loss: 0.15 - ETA: 5s - loss: 0.1496 - 131s 6s/step - loss: 0.1467 - val_loss: 0.2464
#
# Epoch 00050: val_loss improved from 0.25705 to 0.24636, saving model to weights_schrauben_more_data3.h5
# Epoch 51/100
# 22/22 [==============================] - ETA: 1:02 - loss: 0.116 - ETA: 1:07 - loss: 0.125 - ETA: 1:09 - loss: 0.184 - ETA: 1:09 - loss: 0.164 - ETA: 1:04 - loss: 0.151 - ETA: 1:07 - loss: 0.138 - ETA: 1:04 - loss: 0.129 - ETA: 1:03 - loss: 0.138 - ETA: 59s - loss: 0.144 - ETA: 54s - loss: 0.14 - ETA: 52s - loss: 0.14 - ETA: 49s - loss: 0.13 - ETA: 44s - loss: 0.13 - ETA: 38s - loss: 0.13 - ETA: 33s - loss: 0.12 - ETA: 29s - loss: 0.12 - ETA: 24s - loss: 0.12 - ETA: 19s - loss: 0.12 - ETA: 14s - loss: 0.12 - ETA: 9s - loss: 0.1187 - ETA: 4s - loss: 0.124 - 106s 5s/step - loss: 0.1257 - val_loss: 0.3033
#
# Epoch 00051: val_loss did not improve
# Epoch 52/100
# 22/22 [==============================] - ETA: 56s - loss: 0.13 - ETA: 1:15 - loss: 0.129 - ETA: 1:37 - loss: 0.132 - ETA: 1:27 - loss: 0.123 - ETA: 1:22 - loss: 0.124 - ETA: 1:16 - loss: 0.118 - ETA: 1:12 - loss: 0.116 - ETA: 1:13 - loss: 0.112 - ETA: 1:07 - loss: 0.115 - ETA: 1:01 - loss: 0.133 - ETA: 56s - loss: 0.132 - ETA: 49s - loss: 0.12 - ETA: 45s - loss: 0.12 - ETA: 40s - loss: 0.12 - ETA: 36s - loss: 0.12 - ETA: 30s - loss: 0.12 - ETA: 26s - loss: 0.12 - ETA: 21s - loss: 0.12 - ETA: 16s - loss: 0.13 - ETA: 10s - loss: 0.12 - ETA: 5s - loss: 0.1285 - 120s 5s/step - loss: 0.1260 - val_loss: 0.4306
#
# Epoch 00052: val_loss did not improve
# Epoch 53/100
# 22/22 [==============================] - ETA: 2:13 - loss: 0.175 - ETA: 1:27 - loss: 0.141 - ETA: 1:31 - loss: 0.143 - ETA: 1:34 - loss: 0.150 - ETA: 1:23 - loss: 0.139 - ETA: 1:25 - loss: 0.129 - ETA: 1:19 - loss: 0.122 - ETA: 1:12 - loss: 0.119 - ETA: 1:09 - loss: 0.122 - ETA: 1:04 - loss: 0.132 - ETA: 1:01 - loss: 0.126 - ETA: 55s - loss: 0.140 - ETA: 49s - loss: 0.13 - ETA: 43s - loss: 0.13 - ETA: 37s - loss: 0.13 - ETA: 32s - loss: 0.13 - ETA: 27s - loss: 0.13 - ETA: 21s - loss: 0.13 - ETA: 16s - loss: 0.13 - ETA: 11s - loss: 0.13 - ETA: 5s - loss: 0.1364 - 123s 6s/step - loss: 0.1341 - val_loss: 0.3768
#
# Epoch 00053: val_loss did not improve
# Epoch 54/100
# 22/22 [==============================] - ETA: 56s - loss: 0.18 - ETA: 1:31 - loss: 0.125 - ETA: 1:36 - loss: 0.110 - ETA: 1:35 - loss: 0.098 - ETA: 1:34 - loss: 0.101 - ETA: 1:20 - loss: 0.116 - ETA: 1:16 - loss: 0.123 - ETA: 1:09 - loss: 0.125 - ETA: 1:11 - loss: 0.120 - ETA: 1:06 - loss: 0.128 - ETA: 1:02 - loss: 0.119 - ETA: 55s - loss: 0.121 - ETA: 50s - loss: 0.12 - ETA: 43s - loss: 0.12 - ETA: 39s - loss: 0.12 - ETA: 32s - loss: 0.12 - ETA: 26s - loss: 0.11 - ETA: 21s - loss: 0.12 - ETA: 16s - loss: 0.12 - ETA: 10s - loss: 0.13 - ETA: 5s - loss: 0.1363 - 126s 6s/step - loss: 0.1390 - val_loss: 0.4449
#
# Epoch 00054: val_loss did not improve
# Epoch 55/100
# 22/22 [==============================] - ETA: 45s - loss: 0.24 - ETA: 1:28 - loss: 0.159 - ETA: 1:25 - loss: 0.124 - ETA: 1:24 - loss: 0.161 - ETA: 1:22 - loss: 0.151 - ETA: 1:11 - loss: 0.146 - ETA: 1:03 - loss: 0.137 - ETA: 59s - loss: 0.133 - ETA: 1:00 - loss: 0.129 - ETA: 57s - loss: 0.136 - ETA: 55s - loss: 0.13 - ETA: 50s - loss: 0.13 - ETA: 46s - loss: 0.13 - ETA: 41s - loss: 0.12 - ETA: 36s - loss: 0.13 - ETA: 31s - loss: 0.12 - ETA: 26s - loss: 0.13 - ETA: 21s - loss: 0.12 - ETA: 15s - loss: 0.12 - ETA: 10s - loss: 0.12 - ETA: 5s - loss: 0.1275 - 121s 5s/step - loss: 0.1312 - val_loss: 0.3777
#
# Epoch 00055: val_loss did not improve
# Epoch 56/100
# 22/22 [==============================] - ETA: 33s - loss: 0.28 - ETA: 54s - loss: 0.32 - ETA: 44s - loss: 0.25 - ETA: 57s - loss: 0.22 - ETA: 58s - loss: 0.20 - ETA: 56s - loss: 0.19 - ETA: 1:00 - loss: 0.189 - ETA: 55s - loss: 0.177 - ETA: 54s - loss: 0.16 - ETA: 52s - loss: 0.15 - ETA: 46s - loss: 0.14 - ETA: 43s - loss: 0.14 - ETA: 40s - loss: 0.14 - ETA: 37s - loss: 0.13 - ETA: 34s - loss: 0.13 - ETA: 28s - loss: 0.13 - ETA: 24s - loss: 0.13 - ETA: 19s - loss: 0.13 - ETA: 14s - loss: 0.14 - ETA: 9s - loss: 0.1416 - ETA: 4s - loss: 0.140 - 109s 5s/step - loss: 0.1384 - val_loss: 0.3815
#
# Epoch 00056: val_loss did not improve
# Epoch 57/100
# 22/22 [==============================] - ETA: 1:25 - loss: 0.059 - ETA: 1:13 - loss: 0.085 - ETA: 1:22 - loss: 0.108 - ETA: 1:17 - loss: 0.130 - ETA: 1:11 - loss: 0.119 - ETA: 1:10 - loss: 0.128 - ETA: 1:10 - loss: 0.143 - ETA: 1:00 - loss: 0.133 - ETA: 58s - loss: 0.127 - ETA: 55s - loss: 0.12 - ETA: 53s - loss: 0.11 - ETA: 52s - loss: 0.11 - ETA: 46s - loss: 0.11 - ETA: 41s - loss: 0.10 - ETA: 37s - loss: 0.10 - ETA: 32s - loss: 0.10 - ETA: 27s - loss: 0.09 - ETA: 21s - loss: 0.15 - ETA: 15s - loss: 0.15 - ETA: 10s - loss: 0.15 - ETA: 5s - loss: 0.1580 - 119s 5s/step - loss: 0.1544 - val_loss: 0.4293
#
# Epoch 00057: val_loss did not improve
# Epoch 58/100
# 22/22 [==============================] - ETA: 1:23 - loss: 0.148 - ETA: 1:48 - loss: 0.129 - ETA: 1:33 - loss: 0.248 - ETA: 1:27 - loss: 0.204 - ETA: 1:18 - loss: 0.189 - ETA: 1:11 - loss: 0.169 - ETA: 1:05 - loss: 0.151 - ETA: 1:04 - loss: 0.143 - ETA: 59s - loss: 0.136 - ETA: 59s - loss: 0.13 - ETA: 54s - loss: 0.12 - ETA: 50s - loss: 0.12 - ETA: 46s - loss: 0.12 - ETA: 40s - loss: 0.15 - ETA: 34s - loss: 0.15 - ETA: 30s - loss: 0.17 - ETA: 25s - loss: 0.17 - ETA: 19s - loss: 0.17 - ETA: 15s - loss: 0.16 - ETA: 10s - loss: 0.17 - ETA: 4s - loss: 0.1737 - 113s 5s/step - loss: 0.1717 - val_loss: 0.3355
#
# Epoch 00058: val_loss did not improve
# Epoch 59/100
# 22/22 [==============================] - ETA: 30s - loss: 0.13 - ETA: 38s - loss: 0.11 - ETA: 46s - loss: 0.19 - ETA: 50s - loss: 0.15 - ETA: 50s - loss: 0.14 - ETA: 54s - loss: 0.15 - ETA: 57s - loss: 0.15 - ETA: 56s - loss: 0.15 - ETA: 50s - loss: 0.14 - ETA: 48s - loss: 0.17 - ETA: 46s - loss: 0.16 - ETA: 46s - loss: 0.17 - ETA: 41s - loss: 0.17 - ETA: 36s - loss: 0.17 - ETA: 33s - loss: 0.18 - ETA: 28s - loss: 0.17 - ETA: 24s - loss: 0.16 - ETA: 19s - loss: 0.17 - ETA: 14s - loss: 0.16 - ETA: 9s - loss: 0.1638 - ETA: 4s - loss: 0.158 - 108s 5s/step - loss: 0.1551 - val_loss: 0.3428
#
# Epoch 00059: val_loss did not improve
# Epoch 60/100
# 22/22 [==============================] - ETA: 2:03 - loss: 0.071 - ETA: 1:30 - loss: 0.090 - ETA: 1:25 - loss: 0.106 - ETA: 1:33 - loss: 0.114 - ETA: 1:28 - loss: 0.116 - ETA: 1:21 - loss: 0.125 - ETA: 1:23 - loss: 0.120 - ETA: 1:16 - loss: 0.125 - ETA: 1:15 - loss: 0.124 - ETA: 1:09 - loss: 0.120 - ETA: 1:00 - loss: 0.120 - ETA: 57s - loss: 0.116 - ETA: 52s - loss: 0.11 - ETA: 45s - loss: 0.16 - ETA: 42s - loss: 0.16 - ETA: 36s - loss: 0.16 - ETA: 29s - loss: 0.16 - ETA: 23s - loss: 0.15 - ETA: 17s - loss: 0.15 - ETA: 11s - loss: 0.15 - ETA: 5s - loss: 0.1543 - 127s 6s/step - loss: 0.1537 - val_loss: 0.3566
#
# Epoch 00060: val_loss did not improve
# Epoch 00060: early stopping

# %% [markdown]
# # Perform detection on image

# %%
model.load_weights("weigh.h5")

# %%
OBJ_THRESHOLD    = 0.2#0.5
NMS_THRESHOLD    = 0.1#0.45

# %%
image = cv2.imread('../data/TEST_images/35091_1_600x600.jpg')

def predict(image, OBJ_THRESHOLD=0.15,NMS_THRESHOLD=0.1):
    """nms=non max suppression"""
    dummy_array = np.zeros((1,1,1,1,TRUE_BOX_BUFFER,4))

    plt.figure(figsize=(10,10))

    input_image = cv2.resize(image, (416, 416))
    input_image = input_image / 255.
    input_image = input_image[:,:,::-1]
    input_image = np.expand_dims(input_image, 0)

    netout = model.predict([input_image, dummy_array])

    boxes = decode_netout(netout[0], 
                          obj_threshold=OBJ_THRESHOLD,
                          nms_threshold=NMS_THRESHOLD,
                          anchors=ANCHORS, 
                          nb_class=CLASS)

    image = draw_boxes(image, boxes, labels=LABELS)
    print("Schrauben detected:", len(boxes))
    plt.imshow(image[:,:,::-1]); plt.show()

    

predict(image)
# Out:
# Schrauben detected: 3

# %% [markdown]
# for obj_threshold in np.arange(0.1,0.6,0.1):
#     for nms_threshold in np.arange(0.1,0.6,0.1):
#         print("thresholds: obj=", obj_threshold, " nms=", nms_threshold)
#         predict(image,obj_threshold,nms_threshold)

# %%
image = cv2.imread('../data/TEST_images/duebel_schraube.jpg')
predict(image, 0.1,0.15)
# Out:
# Schrauben detected: 3

# %%
image = cv2.imread('../data/raw/IMG_20180724_130904.jpg')
predict(image, 0.25,0.1)
# Out:
# Schrauben detected: 3

# %% [markdown]
# # Perform detection on video

# %%
model.load_weights("weights_schrauben_more_data3.h5")

dummy_array = np.zeros((1,1,1,1,TRUE_BOX_BUFFER,4))

# %%
video_reader = cv2.VideoCapture(0)

nb_frames = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
frame_h = int(video_reader.get(cv2.CAP_PROP_FRAME_HEIGHT))
frame_w = int(video_reader.get(cv2.CAP_PROP_FRAME_WIDTH))

video_writer = cv2.VideoWriter(video_out,
                               cv2.VideoWriter_fourcc(*'XVID'), 
                               50.0, 
                               (frame_w, frame_h))

for i in tqdm(range(nb_frames)):
    ret, image = video_reader.read()
    
    input_image = cv2.resize(image, (416, 416))
    input_image = input_image / 255.
    input_image = input_image[:,:,::-1]
    input_image = np.expand_dims(input_image, 0)

    netout = model.predict([input_image, dummy_array])

    boxes = decode_netout(netout[0], 
                          obj_threshold=0.3,
                          nms_threshold=NMS_THRESHOLD,
                          anchors=ANCHORS, 
                          nb_class=CLASS)
    image = draw_boxes(image, boxes, labels=LABELS)

    video_writer.write(np.uint8(image))
    
video_reader.release()
video_writer.release()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-7bb6c877c08e> in <module>()
#       6 frame_w = int(video_reader.get(cv2.CAP_PROP_FRAME_WIDTH))
#       7
# ----> 8 video_writer = cv2.VideoWriter(video_out,
#       9                                cv2.VideoWriter_fourcc(*'XVID'),
#      10                                50.0,
#
# NameError: name 'video_out' is not defined
